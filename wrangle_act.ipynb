# %%
import pandas as pd
df = pd.read_csv('twitter_archive_enhanced.csv') 
df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df.shape
# Out:
# (2356, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df[df.rating_denominator == 2]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2335  666287406224695296                    NaN                  NaN
#
#                       timestamp  \
# 2335  2015-11-16 16:11:11 +0000
#
#                                                  source  \
# 2335  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2335                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2335  https://twitter.com/dog_rates/status/666287406...                 1
#
#       rating_denominator name doggo floofer pupper puppo
# 2335                   2   an  None    None   None  None

# %%
image = pd.read_csv('image_predictions.tsv', sep='\t')

# %%
image
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image.tweet_id.value_counts()
# Out:
# 685532292383666176    1
# 826598365270007810    1
# 692158366030913536    1
# 714606013974974464    1
# 715696743237730304    1
# 776477788987613185    1
# 772114945936949249    1
# 699775878809702401    1
# 780858289093574656    1
# 700462010979500032    1
# 732726085725589504    1
# 738883359779196928    1
# 798644042770751489    1
# 743510151680958465    1
# 837012587749474308    1
# 833722901757046785    1
# 668620235289837568    1
# 842765311967449089    1
# 685315239903100929    1
# 673686845050527744    1
# 680473011644985345    1
# 666051853826850816    1
# 675853064436391936    1
# 693231807727280129    1
# 705475953783398401    1
# 829449946868879360    1
# 759923798737051648    1
# 667160273090932737    1
# 680934982542561280    1
# 743545585370791937    1
#                      ..
# 794926597468000259    1
# 776113305656188928    1
# 825026590719483904    1
# 834209720923721728    1
# 775733305207554048    1
# 669564461267722241    1
# 879492040517615616    1
# ...

# %%
sum(image.duplicated())
# Out:
# 0

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Fail
# 2: 892177421306343426
# Fail
# 3: 891815181378084864
# Fail
# 4: 891689557279858688
# Fail
# 5: 891327558926688256
# Fail
# 6: 891087950875897856
# Fail
# 7: 890971913173991426
# Fail
# 8: 890729181411237888
# Fail
# 9: 890609185150312448
# Fail
# 10: 890240255349198849
# Fail
# 11: 890006608113172480
# Fail
# 12: 889880896479866881
# Fail
# 13: 889665388333682689
# Fail
# 14: 889638837579907072
# Fail
# 15: 889531135344209921
# Fail
# 16: 889278841981685760
# Fail
# 17: 888917238123831296
# Fail
# 18: 888804989199671297
# Fail
# 19: 888554962724278272
# Fail
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Fail
# 22: 887705289381826560
# Fail
# 23: 887517139158093824
# Fail
# 24: 887473957103951883
# Fail
# 25: 887343217045368832
# Fail
# 26: 887101392804085760
# Fail
# 27: 886983233522544640
# Fail
# 28: 886736880519319552
# Fail
# 29: 886680336477933568
# Fail
# 30: 886366144734445568
# Fail
# 31: 886267009285017600
# Fail
# ...

# %%
import json

# %%
with open('tweet-json.txt') as json_file:
    json_info = pd.DataFrame(columns = ['tweet_id', 
                                        'favorites', 
                                        'retweets'])
    for line in json_file:
        tweet = json.loads(line)
        json_info = json_info.append({
            'tweet_id': tweet['id'],
            'favorites': tweet['favorite_count'],
            'retweets': tweet['retweet_count']
        }, ignore_index=True)

# %%
json_info
# Out:
#                 tweet_id favorites retweets
# 0     892420643555336193     39467     8853
# 1     892177421306343426     33819     6514
# 2     891815181378084864     25461     4328
# 3     891689557279858688     42908     8964
# 4     891327558926688256     41048     9774
# 5     891087950875897856     20562     3261
# 6     890971913173991426     12041     2158
# 7     890729181411237888     56848    16716
# 8     890609185150312448     28226     4429
# 9     890240255349198849     32467     7711
# 10    890006608113172480     31166     7624
# 11    889880896479866881     28268     5156
# 12    889665388333682689     38818     8538
# 13    889638837579907072     27672     4735
# 14    889531135344209921     15359     2321
# 15    889278841981685760     25652     5637
# 16    888917238123831296     29611     4709
# 17    888804989199671297     26080     4559
# 18    888554962724278272     20290     3732
# 19    888078434458587136     22201     3653
# ...

# %%
json_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id     2354 non-null object
# favorites    2354 non-null object
# retweets     2354 non-null object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %%
sum(json_info.duplicated())
# Out:
# 0

# %%
## Quality Issues
#### Twitter Archive Enhaced data
# 1) Timestamp includes date and time       
# 2) Separate Timezone from time column     
# 3) Entry 2335 denominator 2 instead of 10 
# 4) Remove data points that are retweets 181 (after merge)

# Quality Issues - Image Data
# 1) Dog breed capital                      
# 2) Dog names need _ to be replaced by ' ' 
# 3) Headings need fixing                   
# 4) Some non-dog images included - remove these   
# 5) Change tweet_id from object to int in order to merge both tables 


#Structural Issues
# Twitter Archive Enhaced data:
# 1) Dog types should be included in one column
# 2) 3 data sets should be merged

# %%
df_clean = df.copy()
image_clean = image.copy()
json_info_clean = json_info.copy()

# %%
#Define
#1) Timestamp includes both date and time in one column making it difficult to analyse
# Both should be moved to separate columns and the timestamp column should be dropped.

# %%
df.head(1)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None

# %%
#Code
df_clean['Date'] = df_clean['timestamp'].str[:10]

# %%
df_clean['Time'] = df_clean['timestamp'].str[-13:]

# %%
df_clean = df_clean.drop('timestamp', axis=1)

# %%
#Test
df_clean.head(1)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
#
#    rating_denominator     name doggo floofer pupper puppo        Date  \
# 0                  10  Phineas  None    None   None  None  2017-08-01
#
#             Time
# 0  6:23:56 +0000

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# ...

# %%
#Define
#Remove timezone into a separate column

# %%
#Code
df_clean['GMT'] = df_clean['Time'].str[-5:]
df_clean['Time'] = df_clean['Time'].str[:8]

# %%
#Test
df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
#Define
#Entry 2335 denominator 2 instead of 10 - Change 2 to be replaced by 10

# %%
#Code
df_clean.rating_denominator = df_clean.rating_denominator.replace(2, 10)

# %%
#Test
df_clean[df_clean.rating_denominator == 2]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, Date, Time, GMT]
# Index: []

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 19 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# ...

# %%
#Define
# Move dog nicknames to one column as these are not variables but values.

# %%
df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 19 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# ...

# %%
import numpy as np

# %%
df_clean.loc[df_clean.doggo == 'doggo', 'stage'] = 'doggo'
df_clean.loc[df_clean.doggo == 'pupper', 'stage'] = 'pupper'
df_clean.loc[df_clean.doggo == 'floofer', 'stage'] = 'floofer'
# Handle multiple stages
df_clean.loc[df_clean.doggo == 'doggopupper', 'stage'] = 'doggo,pupper'
df_clean.loc[df_clean.doggo == 'doggopuppo', 'stage'] = 'doggo,puppo'
df_clean.loc[df_clean.doggo == 'doggofloofer', 'stage'] = 'doggo,floofer'
# Handle missing values
df_clean.loc[df_clean.doggo == '', 'stage'] = np.nan

# %%
# Handle missing values
df_clean.loc[df_clean.doggo == '', 'stage'] = np.nan

# %%
df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
# Image data
# Define
# Dog breed needs to have capital letters

# %%
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#Code
image_clean.p1 = image_clean.p1.str.capitalize()
image_clean
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
image_clean.p2 = image_clean.p2.str.capitalize()
image_clean
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
image_clean.p3 = image_clean.p3.str.capitalize()

# %%
#Test
image
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
#Define
# Replace the '_' in the dog breed columns to ' ' spaces.

# %%
#Code
image_clean.p1 = [x.strip().replace('_', ' ') for x in image_clean.p1]

# %%
image_clean.p2 = [x.strip().replace('_', ' ') for x in image_clean.p2]

# %%
image_clean.p3 = [x.strip().replace('_', ' ') for x in image_clean.p3]

# %%
#Test
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh springer spaniel  0.465074    True              Collie
# 1        1                 Redbone  0.506826    True  Miniature pinscher
# 2        1         German shepherd  0.596461    True            Malinois
# 3        1     Rhodesian ridgeback  0.408143    True             Redbone
# 4        1      Miniature pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#Define
#Replace the column headings to make them clear to new users
image_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh springer spaniel  0.465074    True              Collie
# 1        1                 Redbone  0.506826    True  Miniature pinscher
# 2        1         German shepherd  0.596461    True            Malinois
# 3        1     Rhodesian ridgeback  0.408143    True             Redbone
# 4        1      Miniature pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#Code
image_clean = image_clean.rename(columns = {'p1':'picture1', 'p1_conf':'picture1_accuracy', 'p1_dog':'picture1_confirmation','p2':'picture2', 'p2_conf':'picture2_accuracy', 'p2_dog':'picture2_confirmation', 'p3':'picture3', 'p3_conf':'p3_accuracy', 'p3_dog':'p3_confirmation' })

# %%
#Test
image_clean
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
#Define
#Get rid of the images that are not dogs. Remove rows with False entry.

# %%
#Code
image_clean1 = image_clean[image_clean.picture1_confirmation != False]
image_clean1 = image_clean[image_clean.picture2_confirmation != False]
image_clean1 = image_clean[image_clean.p3_confirmation != False]

# %%
#Test
image_clean1
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11    666071193221509120    https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# 12    666073100786774016    https://pbs.twimg.com/media/CT5d9DZXAAALcwe.jpg
# ...

# %%
#Define
#Merge 2 datasets json file and twitter archive enhanced

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 19 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# ...

# %%
json_info_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id     2354 non-null object
# favorites    2354 non-null object
# retweets     2354 non-null object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %%
json_info_clean.tweet_id = json_info_clean.tweet_id.astype(int)

# %%
json_info_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id     2354 non-null int64
# favorites    2354 non-null object
# retweets     2354 non-null object
# dtypes: int64(1), object(2)
# memory usage: 55.2+ KB

# %%
#Code
df_clean = pd.merge(df_clean, json_info_clean,
              on=['tweet_id'], how='left')

# %%
#Test
df_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 21 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# ...

# %%
#Define
#Remove data points that are retweets 181

# %%
#Code
df_clean1 = df_clean.copy()

# %%
df_clean1.retweeted_status_id.astype(float)
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19      8.874740e+17
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
#             ...
# 2326             NaN
# 2327             NaN
# 2328             NaN
# 2329             NaN
# 2330             NaN
# 2331             NaN
# 2332             NaN
# 2333             NaN
# 2334             NaN
# 2335             NaN
# 2336             NaN
# 2337             NaN
# ...

# %%
df_clean1 = df_clean1[df_clean['retweeted_status_id'].isnull()]

# %%
df_clean1
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_clean1[df_clean1.retweeted_status_id.notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, Date, Time, GMT, favorites, retweets]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_clean1 = pd.merge(df_clean1, image_clean,
              on=['tweet_id'], how='left')
df_clean1
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
#insight 1 - Dog stage of most retweeted tweet (datasets has to be merged)
df_clean1.retweets.max()
# Out:
# 79515

# %%
#Answer: tweet 744234799360020481	 Dog stage is doggo
df_clean1[df_clean1.retweets == 79515]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 862  744234799360020481                    NaN                  NaN
#
#                                                 source  \
# 862  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 862  Here's a doggo realizing you can stand in a po...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 862                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 862  https://twitter.com/dog_rates/status/744234799...                13
#
#           ...        img_num            picture1 picture1_accuracy  \
# 862       ...            1.0  Labrador retriever          0.825333
#
#     picture1_confirmation  picture2 picture2_accuracy picture2_confirmation  \
# ...

# %%
#insight 2 - highest rating dog with number of retweets
df_clean1.rating_numerator.max()
# Out:
# 1776

# %%
#Answer: 2772 retweets for highest rated dog with 1776/10
df_clean1[df_clean1.rating_numerator == 1776]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 804  749981277374128128                    NaN                  NaN
#
#                                                 source  \
# 804  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  retweeted_status_id  \
# 804  This is Atticus. He's quite simply America af....                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 804                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 804  https://twitter.com/dog_rates/status/749981277...              1776
#
#           ...        img_num picture1 picture1_accuracy picture1_confirmation  \
# 804       ...            1.0  Bow tie          0.533941                 False
#
#        picture2 picture2_accuracy picture2_confirmation  picture3 p3_accuracy  \
# ...

# %%
#insight 3 - dog name of least favourite tweet
df_clean1.favorites.min()
# Out:
# 52

# %%
#Answer - no dog name for least favorite tweet
df_clean1[df_clean1.favorites == 52]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1116  707983188426153984           7.079801e+17         2.319108e+09
#
#                                                  source  \
# 1116  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1116  @serial @MrRoles OH MY GOD I listened to all o...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 1116                       NaN                        NaN           NaN
#
#       rating_numerator       ...        img_num picture1 picture1_accuracy  \
# 1116                12       ...            NaN      NaN               NaN
#
#      picture1_confirmation picture2 picture2_accuracy picture2_confirmation  \
# 1116                   NaN      NaN               NaN                   NaN
#
#      picture3 p3_accuracy p3_confirmation
# 1116      NaN         NaN             NaN
#
# ...

# %%
#visialistion - tweets over time

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 32 columns):
# tweet_id                      2175 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null int64
# rating_denominator            2175 non-null int64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# puppo                         2175 non-null object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
#Visualisation showing number of tweets deteriorating over time.
plt.hist(data = df_clean, x = 'Date')
plt.title('Tweets Over Time')
plt.xlabel('Time')
plt.ylabel('Tweets');

# %%
df_clean.to_csv('twitter_archive_master.csv', index=False)
